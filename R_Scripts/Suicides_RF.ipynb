# %%
options(scipen=999) # Removes scientific notation (useful for when we want readable plots)
options(repr.plot.width=25, repr.plot.height=15) # Make plots larger in Jupyter output
library(dplyr)
library(rnaturalearth)
library(rnaturalearthdata)
library(ggplot2)
library(sf)
library(plotly)
library(ggthemes)
library(ggthemr)
ggthemr('dust')
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Linking to GEOS 3.10.2, GDAL 3.4.2, PROJ 8.2.1; sf_use_s2() is TRUE
#
#
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout

# %%
suicides <- read.csv("https://raw.githubusercontent.com/popsnot/DATA201-Group-Project-2022/main/suicide-death-rates.csv") 
head(suicides) # reading csv directly from our github
names(suicides) <- c('Country', 'Code', 'Year', 'Suicides_Per100k') #renaming
world <- ne_countries(scale = "medium", returnclass = "sf")

world = select(world, c(gu_a3, geometry)) # selecting chosen column

names(world) <- c('Code', 'Geometry')
mergedDF = merge(suicides, world, by = "Code") %>%
  arrange(Year)
# Out:
#   Entity      Code Year
# 1 Afghanistan AFG  1990
# 2 Afghanistan AFG  1991
# 3 Afghanistan AFG  1992
# 4 Afghanistan AFG  1993
# 5 Afghanistan AFG  1994
# 6 Afghanistan AFG  1995
#   Deaths...Self.harm...Sex..Both...Age..Age.standardized..Rate.
# 1 8.28
# 2 8.17
# 3 8.14
# 4 8.23
# 5 8.36
# 6 8.41

# %%
names(suicides) <- c('Country', 'Code', 'Year', 'Suicides_Per100k') #renaming
head(suicides)
# Out:
#   Country     Code Year Suicides_Per100k
# 1 Afghanistan AFG  1990 8.28
# 2 Afghanistan AFG  1991 8.17
# 3 Afghanistan AFG  1992 8.14
# 4 Afghanistan AFG  1993 8.23
# 5 Afghanistan AFG  1994 8.36
# 6 Afghanistan AFG  1995 8.41

# %%
world <- ne_countries(scale = "medium", returnclass = "sf")
class(world)
# Out:
# [1] "sf"         "data.frame"

# %%
world = select(world, c(gu_a3, geometry)) # selecting chosen column

# %%
names(world) <- c('Code', 'Geometry') #Naming columns
mergedDF = merge(suicides, world, by = "Code") %>%
  arrange(Year) #Merging by primary key (code) and arranging by year

mergedDF #Double checking our final dataframe

write.csv(mergedDF,
          "\\Users\\lukafoy\\Desktop\\lfo47_riv14_ahr43_oab29_DATA201_submission\\suicidedata.csv",
          row.names = FALSE)
#Writing the dataframe containing all countries to a csv
# Out:
#      Code Country                          Year Suicides_Per100k
# 1    AFG  Afghanistan                      1990  8.28
# 2    AGO  Angola                           1990 17.59
# 3    ALB  Albania                          1990  4.10
# 4    AND  Andorra                          1990  9.71
# 5    ARE  United Arab Emirates             1990  6.85
# 6    ARG  Argentina                        1990  8.57
# 7    ARM  Armenia                          1990  3.37
# 8    ASM  American Samoa                   1990  7.30
# 9    ATG  Antigua and Barbuda              1990  2.34
# 10   AUS  Australia                        1990 12.80
# 11   AUT  Austria                          1990 19.43
# 12   AZE  Azerbaijan                       1990  3.43
# 13   BDI  Burundi                          1990 20.10
# 14   BEL  Belgium                          1990 17.99
# 15   BEN  Benin                            1990 11.05
# 16   BFA  Burkina Faso                     1990 13.91
# 17   BGD  Bangladesh                       1990 11.78
# 18   BGR  Bulgaria                         1990 17.36
# 19   BHR  Bahrain                          1990  5.90
# 20   BHS  Bahamas                          1990  3.01
# 21   BIH  Bosnia and Herzegovina           1990  9.96
# 22   BLR  Belarus                          1990 20.27
# 23   BLZ  Belize                           1990  5.64
# 24   BMU  Bermuda                          1990  5.83
# 25   BOL  Bolivia                          1990  7.78
# 26   BRA  Brazil                           1990  7.25
# 27   BRB  Barbados                         1990  4.54
# 28   BRN  Brunei                           1990  5.72
# 29   BTN  Bhutan                           1990  8.69
# 30   BWA  Botswana                         1990 18.70
# ⋮    ⋮    ⋮                                ⋮    ⋮
# 5971 SWZ  Eswatini                         2019 24.53
# 5972 SYC  Seychelles                       2019  7.76
# 5973 SYR  Syria                            2019  2.29
# 5974 TCD  Chad                             2019 13.03
# 5975 TGO  Togo                             2019 11.77
# 5976 THA  Thailand                         2019  8.63
# 5977 TJK  Tajikistan                       2019  5.59
# 5978 TKM  Turkmenistan                     2019  8.68
# 5979 TLS  Timor                            2019  5.64
# 5980 TON  Tonga                            2019  5.16
# 5981 TTO  Trinidad and Tobago              2019  9.91
# 5982 TUN  Tunisia                          2019  3.30
# 5983 TUR  Turkey                           2019  2.83
# 5984 TWN  Taiwan                           2019 13.37
# 5985 TZA  Tanzania                         2019 10.06
# 5986 UGA  Uganda                           2019 10.79
# 5987 UKR  Ukraine                          2019 26.34
# 5988 URY  Uruguay                          2019 16.52
# 5989 USA  United States                    2019 11.67
# 5990 UZB  Uzbekistan                       2019 11.34
# 5991 VCT  Saint Vincent and the Grenadines 2019  6.50
# 5992 VEN  Venezuela                        2019  7.93
# 5993 VIR  United States Virgin Islands     2019  6.21
# 5994 VNM  Vietnam                          2019  7.95
# 5995 VUT  Vanuatu                          2019 19.28
# 5996 WSM  Samoa                            2019 13.11
# 5997 YEM  Yemen                            2019  6.14
# 5998 ZAF  South Africa                     2019 13.50
# 5999 ZMB  Zambia                           2019 13.83
# 6000 ZWE  Zimbabwe                         2019 23.41
#      Geometry
# 1    MULTIPOLYGON (((74.89131 37...
# 2    MULTIPOLYGON (((14.19082 -5...
# 3    MULTIPOLYGON (((20.06396 42...
# 4    MULTIPOLYGON (((1.706055 42...
# 5    MULTIPOLYGON (((53.92783 24...
# 6    MULTIPOLYGON (((-64.54917 -...
# 7    MULTIPOLYGON (((45.55234 40...
# 8    MULTIPOLYGON (((-170.7263 -...
# 9    MULTIPOLYGON (((-61.71606 1...
# 10   MULTIPOLYGON (((158.8788 -5...
# 11   MULTIPOLYGON (((16.95312 48...
# 12   MULTIPOLYGON (((45.15283 39...
# 13   MULTIPOLYGON (((30.55361 -2...
# 14   MULTIPOLYGON (((4.816016 51...
# 15   MULTIPOLYGON (((3.59541 11....
# 16   MULTIPOLYGON (((0.2174805 1...
# 17   MULTIPOLYGON (((91.94922 21...
# 18   MULTIPOLYGON (((28.58535 43...
# 19   MULTIPOLYGON (((50.60723 25...
# 20   MULTIPOLYGON (((-73.02686 2...
# 21   MULTIPOLYGON (((16.91865 45...
# 22   MULTIPOLYGON (((28.14795 56...
# 23   MULTIPOLYGON (((-87.85293 1...
# 24   MULTIPOLYGON (((-64.73027 3...
# 25   MULTIPOLYGON (((-58.15977 -...
# 26   MULTIPOLYGON (((-48.48589 -...
# 27   MULTIPOLYGON (((-59.49331 1...
# 28   MULTIPOLYGON (((115.0268 4....
# 29   MULTIPOLYGON (((91.63193 27...
# 30   MULTIPOLYGON (((25.25879 -1...
# ⋮    ⋮
# 5971 MULTIPOLYGON (((31.94824 -2...
# 5972 MULTIPOLYGON (((55.54033 -4...
# 5973 MULTIPOLYGON (((42.35898 37...
# 5974 MULTIPOLYGON (((23.98027 19...
# 5975 MULTIPOLYGON (((0.9004883 1...
# 5976 MULTIPOLYGON (((99.66309 6....
# 5977 MULTIPOLYGON (((70.70166 39...
# 5978 MULTIPOLYGON (((53.10957 38...
# 5979 MULTIPOLYGON (((124.3193 -9...
# 5980 MULTIPOLYGON (((-174.9131 -...
# 5981 MULTIPOLYGON (((-61.01211 1...
# 5982 MULTIPOLYGON (((10.95762 33...
# 5983 MULTIPOLYGON (((25.97002 40...
# 5984 MULTIPOLYGON (((118.4074 24...
# 5985 MULTIPOLYGON (((39.71133 -7...
# 5986 MULTIPOLYGON (((33.90322 -1...
# 5987 MULTIPOLYGON (((32.01221 46...
# 5988 MULTIPOLYGON (((-53.37061 -...
# 5989 MULTIPOLYGON (((-155.5813 1...
# 5990 MULTIPOLYGON (((71.77969 39...
# 5991 MULTIPOLYGON (((-61.33437 1...
# 5992 MULTIPOLYGON (((-60.9979 8....
# 5993 MULTIPOLYGON (((-64.76562 1...
# 5994 MULTIPOLYGON (((106.6175 8....
# 5995 MULTIPOLYGON (((169.8963 -2...
# 5996 MULTIPOLYGON (((-171.4541 -...
# 5997 MULTIPOLYGON (((53.76318 12...
# 5998 MULTIPOLYGON (((37.85693 -4...
# 5999 MULTIPOLYGON (((32.91992 -9...
# 6000 MULTIPOLYGON (((31.28789 -2...

# %%
mergeDF_SF <- st_as_sf(mergedDF) # convert to sf object for plotting geometry
mergeDF_SF <- mergeDF_SF %>% 
  filter(Year == "2019" | Year == "1990") # filtering chosen years for comparison

# %%
assoc_graph <- ggplot(data = mergeDF_SF) + # first comparative plot
  geom_sf(aes(fill = Suicides_Per100k), 
          position = "identity") + 
  labs(fill='Suicides Per 100,000')  +
  scale_fill_viridis_c(option = "viridis") +
  facet_grid(.~Year) # separate plot for each year
  
assoc_graph + theme_map() + theme(legend.position = "bottom")
# Out:
# plot without title

# %%
merged_Countries <- mergeDF_SF %>% # filter for chosen countries
  filter(Country == "New Zealand" | Country == "South Korea" | Country == "Netherlands" | Country == "United States")

# %%
ggplot(merged_Countries, # Grouped barplot using ggplot2
       aes(x = factor(Year),
           y = Suicides_Per100k,
           fill = Country)) +
  geom_bar(stat = "identity",
           position = "dodge")
# Out:
# plot without title

# %%
merged_Countries %>%
  ggplot( aes(factor(Year), Suicides_Per100k, color=Country, label= Code)) +
  geom_point(size = 6)+
  labs(title = "Suicides Per 100,000 By Year", x = "Year", y = "Suicide Rates Per 100,000")
# Out:
# plot without title
